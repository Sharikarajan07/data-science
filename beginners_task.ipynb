# %% [markdown]
# <a href="https://colab.research.google.com/github/Sharikarajan07/data-science/blob/main/beginners_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = pd.read_csv('/heart disease.zip')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# Correlation map

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.103240 -0.071966  0.271121  0.219823  0.121243
# sex      -0.103240  1.000000 -0.041119 -0.078974 -0.198258  0.027200
# cp       -0.071966 -0.041119  1.000000  0.038177 -0.081641  0.079294
# trestbps  0.271121 -0.078974  0.038177  1.000000  0.127977  0.181767
# chol      0.219823 -0.198258 -0.081641  0.127977  1.000000  0.026917
# fbs       0.121243  0.027200  0.079294  0.181767  0.026917  1.000000
# restecg  -0.132696 -0.055117  0.043581 -0.123794 -0.147410 -0.104051
# thalach  -0.390227 -0.049365  0.306839 -0.039264 -0.021772 -0.008866
# exang     0.088163  0.139157 -0.401513  0.061197  0.067382  0.049261
# oldpeak   0.208137  0.084687 -0.174733  0.187434  0.064880  0.010859
# slope    -0.169105 -0.026666  0.131633 -0.120445 -0.014248 -0.061902
# ca        0.271551  0.111729 -0.176206  0.104554  0.074259  0.137156
# thal      0.072297  0.198424 -0.163341  0.059276  0.100244 -0.042177
# ...

# %%
data.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   58    0   0       100   248    0        0      122      0      1.0      1
# 6   58    1   0       114   318    0        2      140      0      4.4      0
# 7   55    1   0       160   289    0        0      145      1      0.8      1
# 8   46    1   0       120   249    0        0      144      0      0.8      2
# 9   54    1   0       122   286    0        0      116      1      3.2      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# Line plot

# %%
data.thalach.plot(kind = 'line', color = 'g',label = 'thalach',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.trestbps.plot(color = 'r',label = 'trestbps',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Line Plot')
plt.show()

# %% [markdown]
# Scatter plot

# %%
data.plot(kind='scatter', x='chol', y='thalach',alpha = 0.5,color = 'red')
plt.xlabel('chol')
plt.ylabel('thalach')
plt.title('chol thalach Scatter Plot')
# Out:
# Text(0.5, 1.0, 'chol thalach Scatter Plot')

# %% [markdown]
# Histogram

# %%
data.chol.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %%
data.chol.plot(kind = 'hist',bins = 50)
plt.clf()

# %%
#create dictionary and look its keys and values
dictionary = {'spain' : 'madrid','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
data = pd.read_csv('/heart disease.zip')

# %%
series = data['fbs']
print(type(series))
data_frame = data[['fbs']]
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
x = data['chol']>200
data[x]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 5      58    0   0       100   248    0        0      122      0      1.0
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data[np.logical_and(data['chol']>200, data['trestbps']>100)]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# 6      58    1   0       114   318    0        2      140      0      4.4
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
data.shape
# Out:
# (1025, 14)

# %%
data.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True)
conc_data_row
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
# 5   59    1   1       140   221    0        1      164      1      0.0      2
# 6   60    1   0       125   258    0        0      141      1      2.8      1
# 7   47    1   0       110   275    0        0      118      1      1.0      1
# 8   50    0   0       110   254    0        0      159      0      0.0      2
# 9   54    1   0       120   188    0        1      113      0      1.4      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# ...

# %%
data1 = data['chol'].head()
data2= data['trestbps'].head()
conc_data_col = pd.concat([data1,data2],axis =1)
conc_data_col
# Out:
#    chol  trestbps
# 0   212       125
# 1   203       140
# 2   174       145
# 3   203       148
# 4   294       138

# %%
x = 2
def f():
    x = 3
    return x
print(x)
print(f())
# Out:
# 2
# 3

# %%
x = 5
def f():
    y = 2*x
    return y
print(f())
# Out:
# 10

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %%
def square():
    """ return square of value """
    def add():
        """ add two local variable """
        x = 2
        y = 3
        z = x + y
        return z
    return add()**2
print(square())
# Out:
# 25

# %%
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(5))
print(f(5,4,3))
# Out:
# 8
# 12

# %%
def f(*args):
    for i in args:
        print(i)
f(1)
print("")
f(1,2,3,4)
def f(**kwargs):
    """ print key and value of dictionary"""
    for key, value in kwargs.items():
        print(key, " ", value)
f(country = 'spain', capital = 'madrid', population = 123456)
# Out:
# 1
#
# 1
# 2
# 3
# 4
# country   spain
# capital   madrid
# population   123456

# %%
square = lambda x: x**2
print(square(4))
tot = lambda x,y,z: x+y+z
print(tot(1,2,3))
# Out:
# 16
# 6

# %%
number_list = [1,2,3]
y = map(lambda x:x**2,number_list)
print(list(y))
# Out:
# [1, 4, 9]

# %%
name = "ronaldo"
it = iter(name)
print(next(it))
print(*it)
# Out:
# r
# o n a l d o

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
z_list = list(z)
print(z_list)
# Out:
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip)
print(un_list1)
print(un_list2)
print(type(un_list2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>

# %%
num1 = [1,2,3]
num2 = [i + 1 for i in num1 ]
print(num2)
# Out:
# [2, 3, 4]

# %%
num1 = [5,10,15]
num2 = [i**2 if i == 10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 20]

# %%
threshold = sum(data.chol)/len(data.chol)
data["chol_level"] = ["high" if i > threshold else "low" for i in data.chol]
data.loc[:10,["chol_level","chol"]]
# Out:
#    chol_level  chol
# 0         low   212
# 1         low   203
# 2         low   174
# 3         low   203
# 4        high   294
# 5        high   248
# 6        high   318
# 7        high   289
# 8        high   249
# 9        high   286
# 10        low   149

# %%
data.boxplot(column='chol',by = 'trestbps')
# Out:
# <Axes: title={'center': 'chol'}, xlabel='trestbps'>

# %%
data.dtypes
# Out:
# age             int64
# sex             int64
# cp              int64
# trestbps        int64
# chol            int64
# fbs             int64
# restecg         int64
# thalach         int64
# exang           int64
# oldpeak       float64
# slope           int64
# ca              int64
# thal            int64
# target          int64
# chol_level     object
# dtype: object

# %%
data["age"].value_counts(dropna =False)
# Out:
# 58    68
# 57    57
# 54    53
# 59    46
# 52    43
# 51    39
# 56    39
# 62    37
# 60    37
# 44    36
# 64    34
# 41    32
# 63    32
# 67    31
# 61    31
# 55    30
# 65    27
# 43    26
# 42    26
# 53    26
# 66    25
# 45    25
# 48    23
# 46    23
# 50    21
# 47    18
# 49    17
# 35    15
# 39    14
# 70    14
# 68    12
# 38    12
# 71    11
# 40    11
# 69     9
# 37     6
# 34     6
# 29     4
# 76     3
# 77     3
# 74     3
# Name: age, dtype: int64

# %%
#data frames from dictionary
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country,population]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
#add new columns
df["capital"] = ["madrid","paris"]
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
#Broadcasting
df["income"] = 0
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %%
#plotting all data
data1 = data.loc[:,["trestbps","fbs","chol"]]
data1.plot()
# Out:
# <Axes: >

# %%
data1.plot(subplots = True)
plt.show()

# %%
data1.plot(kind = "scatter",x="Attack",y = "Defense")
plt.show()
